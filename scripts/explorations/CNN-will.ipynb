# %% [markdown]
# ## Convolutional Neural Nets for FKD

# %%
# initiate packages for NN - Theano etc.
# %matplotlib inline

import numpy as np
from sklearn.datasets import fetch_mldata
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
import time

import theano 
from theano import tensor as T
from theano.sandbox.rng_mrg import MRG_RandomStreams as RandomStreams
device = theano.config.device # We're using CPUs (for now)
floatConf = theano.config.floatX # Should be 64 bit for CPUs

np.random.seed(0)

# %%
# load data

import sys, os

pathArr = os.getcwd().split("/")
scriptPath = '/'.join(map(str, pathArr[:len(pathArr)-1]))
sys.path.append(scriptPath)

# import submit module from our tools subfolder
from tools import submit, getdata
# load data

_loaded = getdata.load_data(0, test=True, nonas=True)

FEATURES = _loaded['features']
print 'Number of features:', len(FEATURES)

# load and scale pixel values to [0, 1]
train_data = np.vstack(_loaded['training']['data']) / 255.
if (floatConf == 'float32'):
    train_data = train_data.astype(np.float32)
else:
    train_data = train_data.astype(np.float64)

# load and scale target coordinates to [-1, 1]
train_labels = _loaded['training']['labels']
train_labels = (train_labels - 48) / 48
if (floatConf == 'float32'):
    train_labels = train_labels.astype(np.float32)
else:
    train_labels = train_labels.astype(np.float64)
    
print 'Training dataset size: ', train_data.shape

test_data = _loaded['test']['data']
print 'Test dataset size: ', test_data.shape
# Out:
# Number of features: 30
# Training dataset size:  (2140, 9216)
# Test dataset size:  (1783,)

# %%
# print train_data.shape, train_data.min(), train_data.max()
# print train_labels.shape, train_labels.min(), train_labels.max()
from lasagne import layers
from lasagne.updates import nesterov_momentum
#from nolearn.lasagne import NeuralNet
import nolearn.lasagne

# %%
from lasagne import layers
from lasagne.updates import nesterov_momentum
from nolearn.lasagne import NeuralNet

net1 = NeuralNet(
    layers=[
        ('input', layers.InputLayer),
        ('hidden', layers.DenseLayer),
        ('output', layers.DenseLayer),
        ],
    # layer parameters:
    input_shape=(None, 9216),  # 96x96 input pixels per batch
    hidden_num_units=100,  # number of units in hidden layer
    output_nonlinearity=None,  # output layer uses identity function
    output_num_units=30,  # 30 target values

    # optimization method:
    update=nesterov_momentum,
    update_learning_rate=0.01,
    update_momentum=0.9,

    regression=True,  # flag to indicate we're dealing with regression problem
    max_epochs=400,  # we want to train this many epochs
    verbose=1,
    )

net1.fit(train_data, train_labels)
# Out:
# /Users/will/src/lasagne/lasagne/init.py:86: UserWarning: The uniform initializer no longer uses Glorot et al.'s approach to determine the bounds, but defaults to the range (-0.01, 0.01) instead. Please use the new GlorotUniform initializer to get the old behavior. GlorotUniform is now the default for all layers.
#   warnings.warn("The uniform initializer no longer uses Glorot et al.'s "
#   input             	(None, 9216)        	produces    9216 outputs
#   hidden            	(None, 100)         	produces     100 outputs
#   output            	(None, 30)          	produces      30 outputs
# 00001	#include <Python.h>
# 00002	#include <iostream>
# 00003	#include <math.h>
# 00004	#include <numpy/arrayobject.h>
# 00005	#include <numpy/arrayscalars.h>
# 00006	//////////////////////
# 00007	////  Support Code
# 00008	//////////////////////
# 00009
# 00010
# 00011	    namespace {
# 00012	    struct __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130 {
# 00013	        PyObject* __ERROR;
# 00014
# 00015	        PyObject* storage_V3;
# 00016	PyObject* storage_V1;
# 00017
# 00018
# 00019	        __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130() {}
# 00020	        ~__struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130(void) {
# 00021	            cleanup();
# 00022	        }
# 00023
# 00024	        int init(PyObject* __ERROR, PyObject* storage_V3, PyObject* storage_V1) {
# 00025	            Py_XINCREF(storage_V3);
# 00026	Py_XINCREF(storage_V1);
# 00027	            this->storage_V3 = storage_V3;
# 00028	this->storage_V1 = storage_V1;
# 00029
# 00030
# 00031
# 00032
# 00033	            this->__ERROR = __ERROR;
# 00034	            return 0;
# 00035	        }
# 00036	        void cleanup(void) {
# 00037	            __label_1:
# 00038
# 00039	double __DUMMY_1;
# 00040	__label_3:
# 00041
# 00042	double __DUMMY_3;
# 00043	__label_6:
# 00044
# 00045	double __DUMMY_6;
# 00046
# 00047	            Py_XDECREF(this->storage_V3);
# 00048	Py_XDECREF(this->storage_V1);
# 00049	        }
# 00050	        int run(void) {
# 00051	            int __failure = 0;
# 00052
# 00053	    PyObject* py_V1;
# 00054
# 00055	        PyArrayObject* V1;
# 00056
# 00057	    PyObject* py_V3;
# 00058
# 00059	        PyArrayObject* V3;
# 00060
# 00061	{
# 00062
# 00063	    py_V1 = PyList_GET_ITEM(storage_V1, 0);
# 00064	    {Py_XINCREF(py_V1);}
# 00065
# 00066	        if (py_V1 == Py_None)
# 00067	        {
# 00068
# 00069	        V1 = NULL;
# 00070
# 00071	        }
# 00072	        else
# 00073	        {
# 00074
# 00075	        V1 = (PyArrayObject*)(py_V1);
# 00076	        Py_XINCREF(V1);
# 00077
# 00078	        }
# 00079
# 00080	{
# 00081
# 00082	    py_V3 = PyList_GET_ITEM(storage_V3, 0);
# 00083	    {Py_XINCREF(py_V3);}
# 00084
# 00085	        V3 = (PyArrayObject*)(py_V3);
# 00086	        Py_XINCREF(V3);
# 00087
# 00088	{
# 00089	// Op class DimShuffle
# 00090	if (PyArray_NDIM(V3) != 0){PyErr_SetString(PyExc_NotImplementedError, "input nd"); {
# 00091	        __failure = 5;
# 00092	        if (!PyErr_Occurred()) {
# 00093	            PyErr_SetString(PyExc_RuntimeError,
# 00094	                "Unexpected error in an Op's C code. "
# 00095	                "No Python exception was set.");
# 00096	            }
# 00097	        goto __label_5;};};
# 00098	if (V1) {Py_XDECREF(V1);};
# 00099	{ PyArrayObject * V3__view_or_copy = (PyArrayObject*)PyArray_FromAny((PyObject*)V3, NULL,0, 0, NPY_ARRAY_ALIGNED|NPY_ARRAY_ENSURECOPY, NULL);
# 00100	npy_intp dimensions[2];
# 00101	dimensions[0] = 1;
# 00102	dimensions[1] = 1;
# 00103	npy_intp strides[2];
# 00104	strides[0] = 0;
# 00105	strides[1] = 0;
# 00106	if (strides[2-1] == 0) strides[2-1] = PyArray_DESCR(V3__view_or_copy)->elsize;
# 00107	if (strides[0] == 0) strides[0] = strides[0+1] * dimensions[0+1];
# 00108	V1 = (PyArrayObject*)PyArray_New(&PyArray_Type, 2, dimensions, PyArray_TYPE(V3__view_or_copy), strides, PyArray_DATA(V3__view_or_copy), PyArray_ITEMSIZE(V3__view_or_copy), (NPY_ARRAY_WRITEABLE*PyArray_ISWRITEABLE(V3__view_or_copy)), NULL);
# 00109	if (V1 == NULL) {
# 00110	        __failure = 5;
# 00111	        if (!PyErr_Occurred()) {
# 00112	            PyErr_SetString(PyExc_RuntimeError,
# 00113	                "Unexpected error in an Op's C code. "
# 00114	                "No Python exception was set.");
# 00115	            }
# 00116	        goto __label_5;};;
# 00117	PyArray_UpdateFlags(V1, NPY_ARRAY_UPDATE_ALL);
# 00118
# 00119	#if NPY_API_VERSION < 0x00000007
# 00120	PyArray_BASE(V1) = (PyObject*)V3__view_or_copy;
# 00121	#else
# 00122	PyArray_SetBaseObject(V1, (PyObject*)V3__view_or_copy);
# 00123	#endif
# 00124	};__label_5:
# 00125
# 00126	double __DUMMY_5;
# 00127
# 00128	}
# 00129	__label_4:
# 00130
# 00131	        if (V3) {
# 00132	            Py_XDECREF(V3);
# 00133	        }
# 00134
# 00135	    {Py_XDECREF(py_V3);}
# 00136
# 00137	double __DUMMY_4;
# 00138
# 00139	}
# 00140	__label_2:
# 00141
# 00142	    if (!__failure) {
# 00143
# 00144	        {Py_XDECREF(py_V1);}
# 00145	        if (!V1) {
# 00146	            Py_INCREF(Py_None);
# 00147	            py_V1 = Py_None;
# 00148	        }
# 00149	        else if ((void*)py_V1 != (void*)V1) {
# 00150	            py_V1 = (PyObject*)V1;
# 00151	        }
# 00152
# 00153	        {Py_XINCREF(py_V1);}
# 00154
# 00155	        if (V1 && !PyArray_ISALIGNED((PyArrayObject*) py_V1)) {
# 00156	            PyErr_Format(PyExc_NotImplementedError,
# 00157	                         "c_sync: expected an aligned array, got non-aligned array of type %ld"
# 00158	                         " with %ld dimensions, with 3 last dims "
# 00159	                         "%ld, %ld, %ld"
# 00160	                         " and 3 last strides %ld %ld, %ld.",
# 00161	                         (long int) PyArray_TYPE((PyArrayObject*) py_V1),
# 00162	                         (long int) PyArray_NDIM(V1),
# 00163	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 00164	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-3] : -1,
# 00165	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 00166	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-2] : -1,
# 00167	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 00168	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-1] : -1,
# 00169	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 00170	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-3] : -1,
# 00171	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 00172	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-2] : -1,
# 00173	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 00174	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-1] : -1
# 00175	        );
# 00176	            {
# 00177	        __failure = 2;
# 00178	        if (!PyErr_Occurred()) {
# 00179	            PyErr_SetString(PyExc_RuntimeError,
# 00180	                "Unexpected error in an Op's C code. "
# 00181	                "No Python exception was set.");
# 00182	            }
# 00183	        goto __label_2;}
# 00184	        }
# 00185
# 00186	      PyObject* old = PyList_GET_ITEM(storage_V1, 0);
# 00187	      {Py_XINCREF(py_V1);}
# 00188	      PyList_SET_ITEM(storage_V1, 0, py_V1);
# 00189	      {Py_XDECREF(old);}
# 00190	    }
# 00191
# 00192	        if (V1) {
# 00193	            Py_XDECREF(V1);
# 00194	        }
# 00195
# 00196	    {Py_XDECREF(py_V1);}
# 00197
# 00198	double __DUMMY_2;
# 00199
# 00200	}
# 00201
# 00202
# 00203	        if (__failure) {
# 00204	            // When there is a failure, this code puts the exception
# 00205	            // in __ERROR.
# 00206	            PyObject* err_type = NULL;
# 00207	            PyObject* err_msg = NULL;
# 00208	            PyObject* err_traceback = NULL;
# 00209	            PyErr_Fetch(&err_type, &err_msg, &err_traceback);
# 00210	            if (!err_type) {err_type = Py_None;Py_INCREF(Py_None);}
# 00211	            if (!err_msg) {err_msg = Py_None; Py_INCREF(Py_None);}
# 00212	            if (!err_traceback) {err_traceback = Py_None; Py_INCREF(Py_None);}
# 00213	            PyObject* old_err_type = PyList_GET_ITEM(__ERROR, 0);
# 00214	            PyObject* old_err_msg = PyList_GET_ITEM(__ERROR, 1);
# 00215	            PyObject* old_err_traceback = PyList_GET_ITEM(__ERROR, 2);
# 00216	            PyList_SET_ITEM(__ERROR, 0, err_type);
# 00217	            PyList_SET_ITEM(__ERROR, 1, err_msg);
# 00218	            PyList_SET_ITEM(__ERROR, 2, err_traceback);
# 00219	            {Py_XDECREF(old_err_type);}
# 00220	            {Py_XDECREF(old_err_msg);}
# 00221	            {Py_XDECREF(old_err_traceback);}
# 00222	        }
# 00223	        // The failure code is returned to index what code block failed.
# 00224	        return __failure;
# 00225
# 00226	        }
# 00227	    };
# 00228	    }
# 00229
# 00230
# 00231	        static int __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130_executor(__struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130* self) {
# 00232	            return self->run();
# 00233	        }
# 00234
# 00235	        static void __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130_destructor(void* executor, void* self) {
# 00236	            delete ((__struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130*)self);
# 00237	        }
# 00238
# 00239	//////////////////////
# 00240	////  Functions
# 00241	//////////////////////
# 00242	static PyObject * instantiate(PyObject * self, PyObject *argtuple) {
# 00243	  assert(PyTuple_Check(argtuple));
# 00244	  if (3 != PyTuple_Size(argtuple)){
# 00245	     PyErr_Format(PyExc_TypeError, "Wrong number of arguments, expected 3, got %i", (int)PyTuple_Size(argtuple));
# 00246	     return NULL;
# 00247	  }
# 00248	  __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130* struct_ptr = new __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130();
# 00249	  if (struct_ptr->init( PyTuple_GET_ITEM(argtuple, 0),PyTuple_GET_ITEM(argtuple, 1),PyTuple_GET_ITEM(argtuple, 2) ) != 0) {
# 00250	    delete struct_ptr;
# 00251	    return NULL;
# 00252	  }
# 00253	  PyObject* thunk = PyCObject_FromVoidPtrAndDesc((void*)(&__struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130_executor), struct_ptr, __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130_destructor);
# 00254	  return thunk; }
# 00255
# 00256	//////////////////////
# 00257	////  Module init
# 00258	//////////////////////
# 00259	static PyMethodDef MyMethods[] = {
# 00260		{"instantiate", instantiate, METH_VARARGS, "undocumented"} ,
# 00261		{NULL, NULL, 0, NULL}
# 00262	};
# 00263	PyMODINIT_FUNC init18d5a8a6a9092d5ba63e47774ced3130(void){
# 00264	   import_array();
# 00265	   (void) Py_InitModule("18d5a8a6a9092d5ba63e47774ced3130", MyMethods);
# 00266	}
# 00267
# Problem occurred during compilation with the command line below:
# /usr/bin/clang++ -dynamiclib -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -target-feature -sse4a -target-feature -avx512bw -target-feature +cx16 -target-feature -tbm -target-feature +xsave -target-feature -fma4 -target-feature -avx512vl -target-feature +prfchw -target-feature +bmi2 -target-feature +adx -target-feature -xsavec -target-feature +fsgsbase -target-feature +avx -target-feature -avx512cd -target-feature -avx512pf -target-feature -rtm -target-feature +popcnt -target-feature +fma -target-feature +bmi -target-feature +aes -target-feature +rdrnd -target-feature -xsaves -target-feature +sse4.1 -target-feature +sse4.2 -target-feature +avx2 -target-feature -avx512er -target-feature +sse -target-feature +lzcnt -target-feature +pclmul -target-feature -avx512f -target-feature +f16c -target-feature +ssse3 -target-feature +mmx -target-feature +cmov -target-feature -xop -target-feature +rdseed -target-feature +movbe -target-feature -hle -target-feature +xsaveopt -target-feature -sha -target-feature +sse2 -target-feature +sse3 -target-feature -avx512dq -D NPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -undefined dynamic_lookup -I/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/numpy/core/include -I/Users/will/miniconda3/envs/lnet/include/python2.7 -o /Users/will/.theano/compiledir_Darwin-15.4.0-x86_64-i386-64bit-i386-2.7.11-64/tmpUYuiZ7/18d5a8a6a9092d5ba63e47774ced3130.so /Users/will/.theano/compiledir_Darwin-15.4.0-x86_64-i386-64bit-i386-2.7.11-64/tmpUYuiZ7/mod.cpp -L/Users/will/miniconda3/envs/lnet/lib
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/opt.py", line 1493, in process_node
#     replacements = lopt.transform(node)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/tensor/opt.py", line 4684, in constant_folding
#     no_recycling=[])
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/op.py", line 739, in make_thunk
#     output_storage=node_output_storage)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1073, in make_thunk
#     keep_lock=keep_lock)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1015, in __compile__
#     keep_lock=keep_lock)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1442, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1076, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1354, in compile_cmodule
#     preargs=preargs)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2010, in compile_str
#     (status, compile_stderr.replace('\n', '. ')))
# Exception: ("Compilation failed (return status=1): clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-sse4a'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-tbm'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-fma4'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-rtm'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-hle'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-sha'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: no such file or directory: '+cx16'. clang: error: no such file or directory: '+xsave'. clang: error: no such file or directory: '+prfchw'. clang: error: no such file or directory: '+bmi2'. clang: error: no such file or directory: '+adx'. clang: error: language not recognized: 'savec'. clang: error: no such file or directory: '+fsgsbase'. clang: error: no such file or directory: '+avx'. clang: error: no such file or directory: '+popcnt'. clang: error: no such file or directory: '+fma'. clang: error: no such file or directory: '+bmi'. clang: error: no such file or directory: '+aes'. clang: error: no such file or directory: '+rdrnd'. clang: error: language not recognized: 'saves'. clang: error: no such file or directory: '+sse4.1'. clang: error: no such file or directory: '+sse4.2'. clang: error: no such file or directory: '+avx2'. clang: error: no such file or directory: '+sse'. clang: error: no such file or directory: '+lzcnt'. clang: error: no such file or directory: '+pclmul'. clang: error: no such file or directory: '+f16c'. clang: error: no such file or directory: '+ssse3'. clang: error: no such file or directory: '+mmx'. clang: error: no such file or directory: '+cmov'. clang: error: language not recognized: 'op'. clang: error: no such file or directory: '+rdseed'. clang: error: no such file or directory: '+movbe'. clang: error: no such file or directory: '+xsaveopt'. clang: error: no such file or directory: '+sse2'. clang: error: no such file or directory: '+sse3'. ", ' ...
#
# 00001	#include <Python.h>
# 00002	#include <iostream>
# 00003	#include <math.h>
# 00004	#include <numpy/arrayobject.h>
# 00005	#include <numpy/arrayscalars.h>
# 00006	//////////////////////
# 00007	////  Support Code
# 00008	//////////////////////
# 00009
# 00010
# 00011	    namespace {
# 00012	    struct __struct_compiled_op_a0c0d004885b47900367b972585efa2a {
# 00013	        PyObject* __ERROR;
# 00014
# 00015	        PyObject* storage_V3;
# 00016	PyObject* storage_V1;
# 00017
# 00018
# 00019	        __struct_compiled_op_a0c0d004885b47900367b972585efa2a() {}
# 00020	        ~__struct_compiled_op_a0c0d004885b47900367b972585efa2a(void) {
# 00021	            cleanup();
# 00022	        }
# 00023
# 00024	        int init(PyObject* __ERROR, PyObject* storage_V3, PyObject* storage_V1) {
# 00025	            Py_XINCREF(storage_V3);
# 00026	Py_XINCREF(storage_V1);
# 00027	            this->storage_V3 = storage_V3;
# 00028	this->storage_V1 = storage_V1;
# 00029
# 00030
# 00031
# 00032
# 00033	            this->__ERROR = __ERROR;
# 00034	            return 0;
# 00035	        }
# 00036	        void cleanup(void) {
# 00037	            __label_1:
# 00038
# 00039	double __DUMMY_1;
# 00040	__label_3:
# 00041
# 00042	double __DUMMY_3;
# 00043	__label_6:
# 00044
# 00045	double __DUMMY_6;
# 00046
# 00047	            Py_XDECREF(this->storage_V3);
# 00048	Py_XDECREF(this->storage_V1);
# 00049	        }
# 00050	        int run(void) {
# 00051	            int __failure = 0;
# 00052
# 00053	    PyObject* py_V1;
# 00054
# 00055	        PyArrayObject* V1;
# 00056
# 00057	    PyObject* py_V3;
# 00058
# 00059	        PyArrayObject* V3;
# 00060
# 00061	{
# 00062
# 00063	    py_V1 = PyList_GET_ITEM(storage_V1, 0);
# 00064	    {Py_XINCREF(py_V1);}
# 00065
# 00066	        if (py_V1 == Py_None)
# 00067	        {
# 00068
# 00069	        V1 = NULL;
# 00070
# 00071	        }
# 00072	        else
# 00073	        {
# 00074
# 00075	        V1 = (PyArrayObject*)(py_V1);
# 00076	        Py_XINCREF(V1);
# 00077
# 00078	        }
# 00079
# 00080	{
# 00081
# 00082	    py_V3 = PyList_GET_ITEM(storage_V3, 0);
# 00083	    {Py_XINCREF(py_V3);}
# 00084
# 00085	        V3 = (PyArrayObject*)(py_V3);
# 00086	        Py_XINCREF(V3);
# 00087
# 00088	{
# 00089	// Op class DimShuffle
# 00090	if (PyArray_NDIM(V3) != 0){PyErr_SetString(PyExc_NotImplementedError, "input nd"); {
# 00091	        __failure = 5;
# 00092	        if (!PyErr_Occurred()) {
# 00093	            PyErr_SetString(PyExc_RuntimeError,
# 00094	                "Unexpected error in an Op's C code. "
# 00095	                "No Python exception was set.");
# 00096	            }
# 00097	        goto __label_5;};};
# 00098	if (V1) {Py_XDECREF(V1);};
# 00099	{ PyArrayObject * V3__view_or_copy = (PyArrayObject*)PyArray_FromAny((PyObject*)V3, NULL,0, 0, NPY_ARRAY_ALIGNED|NPY_ARRAY_ENSURECOPY, NULL);
# 00100	npy_intp dimensions[1];
# 00101	dimensions[0] = 1;
# 00102	npy_intp strides[1];
# 00103	strides[0] = 0;
# 00104	if (strides[1-1] == 0) strides[1-1] = PyArray_DESCR(V3__view_or_copy)->elsize;
# 00105	V1 = (PyArrayObject*)PyArray_New(&PyArray_Type, 1, dimensions, PyArray_TYPE(V3__view_or_copy), strides, PyArray_DATA(V3__view_or_copy), PyArray_ITEMSIZE(V3__view_or_copy), (NPY_ARRAY_WRITEABLE*PyArray_ISWRITEABLE(V3__view_or_copy)), NULL);
# 00106	if (V1 == NULL) {
# 00107	        __failure = 5;
# 00108	        if (!PyErr_Occurred()) {
# 00109	            PyErr_SetString(PyExc_RuntimeError,
# 00110	                "Unexpected error in an Op's C code. "
# 00111	                "No Python exception was set.");
# 00112	            }
# 00113	        goto __label_5;};;
# 00114	PyArray_UpdateFlags(V1, NPY_ARRAY_UPDATE_ALL);
# 00115
# 00116	#if NPY_API_VERSION < 0x00000007
# 00117	PyArray_BASE(V1) = (PyObject*)V3__view_or_copy;
# 00118	#else
# 00119	PyArray_SetBaseObject(V1, (PyObject*)V3__view_or_copy);
# 00120	#endif
# 00121	};__label_5:
# 00122
# 00123	double __DUMMY_5;
# 00124
# 00125	}
# 00126	__label_4:
# 00127
# 00128	        if (V3) {
# 00129	            Py_XDECREF(V3);
# 00130	        }
# 00131
# 00132	    {Py_XDECREF(py_V3);}
# 00133
# 00134	double __DUMMY_4;
# 00135
# 00136	}
# 00137	__label_2:
# 00138
# 00139	    if (!__failure) {
# 00140
# 00141	        {Py_XDECREF(py_V1);}
# 00142	        if (!V1) {
# 00143	            Py_INCREF(Py_None);
# 00144	            py_V1 = Py_None;
# 00145	        }
# 00146	        else if ((void*)py_V1 != (void*)V1) {
# 00147	            py_V1 = (PyObject*)V1;
# 00148	        }
# 00149
# 00150	        {Py_XINCREF(py_V1);}
# 00151
# 00152	        if (V1 && !PyArray_ISALIGNED((PyArrayObject*) py_V1)) {
# 00153	            PyErr_Format(PyExc_NotImplementedError,
# 00154	                         "c_sync: expected an aligned array, got non-aligned array of type %ld"
# 00155	                         " with %ld dimensions, with 3 last dims "
# 00156	                         "%ld, %ld, %ld"
# 00157	                         " and 3 last strides %ld %ld, %ld.",
# 00158	                         (long int) PyArray_TYPE((PyArrayObject*) py_V1),
# 00159	                         (long int) PyArray_NDIM(V1),
# 00160	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 00161	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-3] : -1,
# 00162	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 00163	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-2] : -1,
# 00164	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 00165	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-1] : -1,
# 00166	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 00167	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-3] : -1,
# 00168	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 00169	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-2] : -1,
# 00170	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 00171	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-1] : -1
# 00172	        );
# 00173	            {
# 00174	        __failure = 2;
# 00175	        if (!PyErr_Occurred()) {
# 00176	            PyErr_SetString(PyExc_RuntimeError,
# 00177	                "Unexpected error in an Op's C code. "
# 00178	                "No Python exception was set.");
# 00179	            }
# 00180	        goto __label_2;}
# 00181	        }
# 00182
# 00183	      PyObject* old = PyList_GET_ITEM(storage_V1, 0);
# 00184	      {Py_XINCREF(py_V1);}
# 00185	      PyList_SET_ITEM(storage_V1, 0, py_V1);
# 00186	      {Py_XDECREF(old);}
# 00187	    }
# 00188
# 00189	        if (V1) {
# 00190	            Py_XDECREF(V1);
# 00191	        }
# 00192
# 00193	    {Py_XDECREF(py_V1);}
# 00194
# 00195	double __DUMMY_2;
# 00196
# 00197	}
# 00198
# 00199
# 00200	        if (__failure) {
# 00201	            // When there is a failure, this code puts the exception
# 00202	            // in __ERROR.
# 00203	            PyObject* err_type = NULL;
# 00204	            PyObject* err_msg = NULL;
# 00205	            PyObject* err_traceback = NULL;
# 00206	            PyErr_Fetch(&err_type, &err_msg, &err_traceback);
# 00207	            if (!err_type) {err_type = Py_None;Py_INCREF(Py_None);}
# 00208	            if (!err_msg) {err_msg = Py_None; Py_INCREF(Py_None);}
# 00209	            if (!err_traceback) {err_traceback = Py_None; Py_INCREF(Py_None);}
# 00210	            PyObject* old_err_type = PyList_GET_ITEM(__ERROR, 0);
# 00211	            PyObject* old_err_msg = PyList_GET_ITEM(__ERROR, 1);
# 00212	            PyObject* old_err_traceback = PyList_GET_ITEM(__ERROR, 2);
# 00213	            PyList_SET_ITEM(__ERROR, 0, err_type);
# 00214	            PyList_SET_ITEM(__ERROR, 1, err_msg);
# 00215	            PyList_SET_ITEM(__ERROR, 2, err_traceback);
# 00216	            {Py_XDECREF(old_err_type);}
# 00217	            {Py_XDECREF(old_err_msg);}
# 00218	            {Py_XDECREF(old_err_traceback);}
# 00219	        }
# 00220	        // The failure code is returned to index what code block failed.
# 00221	        return __failure;
# 00222
# 00223	        }
# 00224	    };
# 00225	    }
# 00226
# 00227
# 00228	        static int __struct_compiled_op_a0c0d004885b47900367b972585efa2a_executor(__struct_compiled_op_a0c0d004885b47900367b972585efa2a* self) {
# 00229	            return self->run();
# 00230	        }
# 00231
# 00232	        static void __struct_compiled_op_a0c0d004885b47900367b972585efa2a_destructor(void* executor, void* self) {
# 00233	            delete ((__struct_compiled_op_a0c0d004885b47900367b972585efa2a*)self);
# 00234	        }
# 00235
# 00236	//////////////////////
# 00237	////  Functions
# 00238	//////////////////////
# 00239	static PyObject * instantiate(PyObject * self, PyObject *argtuple) {
# 00240	  assert(PyTuple_Check(argtuple));
# 00241	  if (3 != PyTuple_Size(argtuple)){
# 00242	     PyErr_Format(PyExc_TypeError, "Wrong number of arguments, expected 3, got %i", (int)PyTuple_Size(argtuple));
# 00243	     return NULL;
# 00244	  }
# 00245	  __struct_compiled_op_a0c0d004885b47900367b972585efa2a* struct_ptr = new __struct_compiled_op_a0c0d004885b47900367b972585efa2a();
# 00246	  if (struct_ptr->init( PyTuple_GET_ITEM(argtuple, 0),PyTuple_GET_ITEM(argtuple, 1),PyTuple_GET_ITEM(argtuple, 2) ) != 0) {
# 00247	    delete struct_ptr;
# 00248	    return NULL;
# 00249	  }
# 00250	  PyObject* thunk = PyCObject_FromVoidPtrAndDesc((void*)(&__struct_compiled_op_a0c0d004885b47900367b972585efa2a_executor), struct_ptr, __struct_compiled_op_a0c0d004885b47900367b972585efa2a_destructor);
# 00251	  return thunk; }
# 00252
# 00253	//////////////////////
# 00254	////  Module init
# 00255	//////////////////////
# 00256	static PyMethodDef MyMethods[] = {
# 00257		{"instantiate", instantiate, METH_VARARGS, "undocumented"} ,
# 00258		{NULL, NULL, 0, NULL}
# 00259	};
# 00260	PyMODINIT_FUNC inita0c0d004885b47900367b972585efa2a(void){
# 00261	   import_array();
# 00262	   (void) Py_InitModule("a0c0d004885b47900367b972585efa2a", MyMethods);
# 00263	}
# 00264
# Problem occurred during compilation with the command line below:
# /usr/bin/clang++ -dynamiclib -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -target-feature -sse4a -target-feature -avx512bw -target-feature +cx16 -target-feature -tbm -target-feature +xsave -target-feature -fma4 -target-feature -avx512vl -target-feature +prfchw -target-feature +bmi2 -target-feature +adx -target-feature -xsavec -target-feature +fsgsbase -target-feature +avx -target-feature -avx512cd -target-feature -avx512pf -target-feature -rtm -target-feature +popcnt -target-feature +fma -target-feature +bmi -target-feature +aes -target-feature +rdrnd -target-feature -xsaves -target-feature +sse4.1 -target-feature +sse4.2 -target-feature +avx2 -target-feature -avx512er -target-feature +sse -target-feature +lzcnt -target-feature +pclmul -target-feature -avx512f -target-feature +f16c -target-feature +ssse3 -target-feature +mmx -target-feature +cmov -target-feature -xop -target-feature +rdseed -target-feature +movbe -target-feature -hle -target-feature +xsaveopt -target-feature -sha -target-feature +sse2 -target-feature +sse3 -target-feature -avx512dq -D NPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -undefined dynamic_lookup -I/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/numpy/core/include -I/Users/will/miniconda3/envs/lnet/include/python2.7 -o /Users/will/.theano/compiledir_Darwin-15.4.0-x86_64-i386-64bit-i386-2.7.11-64/tmpAkpYZa/a0c0d004885b47900367b972585efa2a.so /Users/will/.theano/compiledir_Darwin-15.4.0-x86_64-i386-64bit-i386-2.7.11-64/tmpAkpYZa/mod.cpp -L/Users/will/miniconda3/envs/lnet/lib
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/opt.py", line 1493, in process_node
#     replacements = lopt.transform(node)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/tensor/opt.py", line 4684, in constant_folding
#     no_recycling=[])
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/op.py", line 739, in make_thunk
#     output_storage=node_output_storage)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1073, in make_thunk
#     keep_lock=keep_lock)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1015, in __compile__
#     keep_lock=keep_lock)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1442, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1076, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1354, in compile_cmodule
#     preargs=preargs)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2010, in compile_str
#     (status, compile_stderr.replace('\n', '. ')))
# Exception: ("Compilation failed (return status=1): clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-sse4a'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-tbm'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-fma4'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-rtm'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-hle'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-sha'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: no such file or directory: '+cx16'. clang: error: no such file or directory: '+xsave'. clang: error: no such file or directory: '+prfchw'. clang: error: no such file or directory: '+bmi2'. clang: error: no such file or directory: '+adx'. clang: error: language not recognized: 'savec'. clang: error: no such file or directory: '+fsgsbase'. clang: error: no such file or directory: '+avx'. clang: error: no such file or directory: '+popcnt'. clang: error: no such file or directory: '+fma'. clang: error: no such file or directory: '+bmi'. clang: error: no such file or directory: '+aes'. clang: error: no such file or directory: '+rdrnd'. clang: error: language not recognized: 'saves'. clang: error: no such file or directory: '+sse4.1'. clang: error: no such file or directory: '+sse4.2'. clang: error: no such file or directory: '+avx2'. clang: error: no such file or directory: '+sse'. clang: error: no such file or directory: '+lzcnt'. clang: error: no such file or directory: '+pclmul'. clang: error: no such file or directory: '+f16c'. clang: error: no such file or directory: '+ssse3'. clang: error: no such file or directory: '+mmx'. clang: error: no such file or directory: '+cmov'. clang: error: language not recognized: 'op'. clang: error: no such file or directory: '+rdseed'. clang: error: no such file or directory: '+movbe'. clang: error: no such file or directory: '+xsaveopt'. clang: error: no such file or directory: '+sse2'. clang: error: no such file or directory: '+sse3'. ", ' ...
#
# 00001	#include <Python.h>
# 00002	#include <iostream>
# 00003	#include <math.h>
# 00004	#include <numpy/arrayobject.h>
# 00005	#include <numpy/arrayscalars.h>
# 00006	//////////////////////
# 00007	////  Support Code
# 00008	//////////////////////
# 00009
# 00010
# 00011	    namespace {
# 00012	    struct __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130 {
# 00013	        PyObject* __ERROR;
# 00014
# 00015	        PyObject* storage_V3;
# 00016	PyObject* storage_V1;
# 00017
# 00018
# 00019	        __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130() {}
# 00020	        ~__struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130(void) {
# 00021	            cleanup();
# 00022	        }
# 00023
# 00024	        int init(PyObject* __ERROR, PyObject* storage_V3, PyObject* storage_V1) {
# 00025	            Py_XINCREF(storage_V3);
# 00026	Py_XINCREF(storage_V1);
# 00027	            this->storage_V3 = storage_V3;
# 00028	this->storage_V1 = storage_V1;
# 00029
# 00030
# 00031
# 00032
# 00033	            this->__ERROR = __ERROR;
# 00034	            return 0;
# 00035	        }
# 00036	        void cleanup(void) {
# 00037	            __label_1:
# 00038
# 00039	double __DUMMY_1;
# 00040	__label_3:
# 00041
# 00042	double __DUMMY_3;
# 00043	__label_6:
# 00044
# 00045	double __DUMMY_6;
# 00046
# 00047	            Py_XDECREF(this->storage_V3);
# 00048	Py_XDECREF(this->storage_V1);
# 00049	        }
# 00050	        int run(void) {
# 00051	            int __failure = 0;
# 00052
# 00053	    PyObject* py_V1;
# 00054
# 00055	        PyArrayObject* V1;
# 00056
# 00057	    PyObject* py_V3;
# 00058
# 00059	        PyArrayObject* V3;
# 00060
# 00061	{
# 00062
# 00063	    py_V1 = PyList_GET_ITEM(storage_V1, 0);
# 00064	    {Py_XINCREF(py_V1);}
# 00065
# 00066	        if (py_V1 == Py_None)
# 00067	        {
# 00068
# 00069	        V1 = NULL;
# 00070
# 00071	        }
# 00072	        else
# 00073	        {
# 00074
# 00075	        V1 = (PyArrayObject*)(py_V1);
# 00076	        Py_XINCREF(V1);
# 00077
# 00078	        }
# 00079
# 00080	{
# 00081
# 00082	    py_V3 = PyList_GET_ITEM(storage_V3, 0);
# 00083	    {Py_XINCREF(py_V3);}
# 00084
# 00085	        V3 = (PyArrayObject*)(py_V3);
# 00086	        Py_XINCREF(V3);
# 00087
# 00088	{
# 00089	// Op class DimShuffle
# 00090	if (PyArray_NDIM(V3) != 0){PyErr_SetString(PyExc_NotImplementedError, "input nd"); {
# 00091	        __failure = 5;
# 00092	        if (!PyErr_Occurred()) {
# 00093	            PyErr_SetString(PyExc_RuntimeError,
# 00094	                "Unexpected error in an Op's C code. "
# 00095	                "No Python exception was set.");
# 00096	            }
# 00097	        goto __label_5;};};
# 00098	if (V1) {Py_XDECREF(V1);};
# 00099	{ PyArrayObject * V3__view_or_copy = (PyArrayObject*)PyArray_FromAny((PyObject*)V3, NULL,0, 0, NPY_ARRAY_ALIGNED|NPY_ARRAY_ENSURECOPY, NULL);
# 00100	npy_intp dimensions[2];
# 00101	dimensions[0] = 1;
# 00102	dimensions[1] = 1;
# 00103	npy_intp strides[2];
# 00104	strides[0] = 0;
# 00105	strides[1] = 0;
# 00106	if (strides[2-1] == 0) strides[2-1] = PyArray_DESCR(V3__view_or_copy)->elsize;
# 00107	if (strides[0] == 0) strides[0] = strides[0+1] * dimensions[0+1];
# 00108	V1 = (PyArrayObject*)PyArray_New(&PyArray_Type, 2, dimensions, PyArray_TYPE(V3__view_or_copy), strides, PyArray_DATA(V3__view_or_copy), PyArray_ITEMSIZE(V3__view_or_copy), (NPY_ARRAY_WRITEABLE*PyArray_ISWRITEABLE(V3__view_or_copy)), NULL);
# 00109	if (V1 == NULL) {
# 00110	        __failure = 5;
# 00111	        if (!PyErr_Occurred()) {
# 00112	            PyErr_SetString(PyExc_RuntimeError,
# 00113	                "Unexpected error in an Op's C code. "
# 00114	                "No Python exception was set.");
# 00115	            }
# 00116	        goto __label_5;};;
# 00117	PyArray_UpdateFlags(V1, NPY_ARRAY_UPDATE_ALL);
# 00118
# 00119	#if NPY_API_VERSION < 0x00000007
# 00120	PyArray_BASE(V1) = (PyObject*)V3__view_or_copy;
# 00121	#else
# 00122	PyArray_SetBaseObject(V1, (PyObject*)V3__view_or_copy);
# 00123	#endif
# 00124	};__label_5:
# 00125
# 00126	double __DUMMY_5;
# 00127
# 00128	}
# 00129	__label_4:
# 00130
# 00131	        if (V3) {
# 00132	            Py_XDECREF(V3);
# 00133	        }
# 00134
# 00135	    {Py_XDECREF(py_V3);}
# 00136
# 00137	double __DUMMY_4;
# 00138
# 00139	}
# 00140	__label_2:
# 00141
# 00142	    if (!__failure) {
# 00143
# 00144	        {Py_XDECREF(py_V1);}
# 00145	        if (!V1) {
# 00146	            Py_INCREF(Py_None);
# 00147	            py_V1 = Py_None;
# 00148	        }
# 00149	        else if ((void*)py_V1 != (void*)V1) {
# 00150	            py_V1 = (PyObject*)V1;
# 00151	        }
# 00152
# 00153	        {Py_XINCREF(py_V1);}
# 00154
# 00155	        if (V1 && !PyArray_ISALIGNED((PyArrayObject*) py_V1)) {
# 00156	            PyErr_Format(PyExc_NotImplementedError,
# 00157	                         "c_sync: expected an aligned array, got non-aligned array of type %ld"
# 00158	                         " with %ld dimensions, with 3 last dims "
# 00159	                         "%ld, %ld, %ld"
# 00160	                         " and 3 last strides %ld %ld, %ld.",
# 00161	                         (long int) PyArray_TYPE((PyArrayObject*) py_V1),
# 00162	                         (long int) PyArray_NDIM(V1),
# 00163	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 00164	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-3] : -1,
# 00165	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 00166	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-2] : -1,
# 00167	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 00168	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-1] : -1,
# 00169	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 00170	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-3] : -1,
# 00171	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 00172	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-2] : -1,
# 00173	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 00174	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-1] : -1
# 00175	        );
# 00176	            {
# 00177	        __failure = 2;
# 00178	        if (!PyErr_Occurred()) {
# 00179	            PyErr_SetString(PyExc_RuntimeError,
# 00180	                "Unexpected error in an Op's C code. "
# 00181	                "No Python exception was set.");
# 00182	            }
# 00183	        goto __label_2;}
# 00184	        }
# 00185
# 00186	      PyObject* old = PyList_GET_ITEM(storage_V1, 0);
# 00187	      {Py_XINCREF(py_V1);}
# 00188	      PyList_SET_ITEM(storage_V1, 0, py_V1);
# 00189	      {Py_XDECREF(old);}
# 00190	    }
# 00191
# 00192	        if (V1) {
# 00193	            Py_XDECREF(V1);
# 00194	        }
# 00195
# 00196	    {Py_XDECREF(py_V1);}
# 00197
# 00198	double __DUMMY_2;
# 00199
# 00200	}
# 00201
# 00202
# 00203	        if (__failure) {
# 00204	            // When there is a failure, this code puts the exception
# 00205	            // in __ERROR.
# 00206	            PyObject* err_type = NULL;
# 00207	            PyObject* err_msg = NULL;
# 00208	            PyObject* err_traceback = NULL;
# 00209	            PyErr_Fetch(&err_type, &err_msg, &err_traceback);
# 00210	            if (!err_type) {err_type = Py_None;Py_INCREF(Py_None);}
# 00211	            if (!err_msg) {err_msg = Py_None; Py_INCREF(Py_None);}
# 00212	            if (!err_traceback) {err_traceback = Py_None; Py_INCREF(Py_None);}
# 00213	            PyObject* old_err_type = PyList_GET_ITEM(__ERROR, 0);
# 00214	            PyObject* old_err_msg = PyList_GET_ITEM(__ERROR, 1);
# 00215	            PyObject* old_err_traceback = PyList_GET_ITEM(__ERROR, 2);
# 00216	            PyList_SET_ITEM(__ERROR, 0, err_type);
# 00217	            PyList_SET_ITEM(__ERROR, 1, err_msg);
# 00218	            PyList_SET_ITEM(__ERROR, 2, err_traceback);
# 00219	            {Py_XDECREF(old_err_type);}
# 00220	            {Py_XDECREF(old_err_msg);}
# 00221	            {Py_XDECREF(old_err_traceback);}
# 00222	        }
# 00223	        // The failure code is returned to index what code block failed.
# 00224	        return __failure;
# 00225
# 00226	        }
# 00227	    };
# 00228	    }
# 00229
# 00230
# 00231	        static int __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130_executor(__struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130* self) {
# 00232	            return self->run();
# 00233	        }
# 00234
# 00235	        static void __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130_destructor(void* executor, void* self) {
# 00236	            delete ((__struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130*)self);
# 00237	        }
# 00238
# 00239	//////////////////////
# 00240	////  Functions
# 00241	//////////////////////
# 00242	static PyObject * instantiate(PyObject * self, PyObject *argtuple) {
# 00243	  assert(PyTuple_Check(argtuple));
# 00244	  if (3 != PyTuple_Size(argtuple)){
# 00245	     PyErr_Format(PyExc_TypeError, "Wrong number of arguments, expected 3, got %i", (int)PyTuple_Size(argtuple));
# 00246	     return NULL;
# 00247	  }
# 00248	  __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130* struct_ptr = new __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130();
# 00249	  if (struct_ptr->init( PyTuple_GET_ITEM(argtuple, 0),PyTuple_GET_ITEM(argtuple, 1),PyTuple_GET_ITEM(argtuple, 2) ) != 0) {
# 00250	    delete struct_ptr;
# 00251	    return NULL;
# 00252	  }
# 00253	  PyObject* thunk = PyCObject_FromVoidPtrAndDesc((void*)(&__struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130_executor), struct_ptr, __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130_destructor);
# 00254	  return thunk; }
# 00255
# 00256	//////////////////////
# 00257	////  Module init
# 00258	//////////////////////
# 00259	static PyMethodDef MyMethods[] = {
# 00260		{"instantiate", instantiate, METH_VARARGS, "undocumented"} ,
# 00261		{NULL, NULL, 0, NULL}
# 00262	};
# 00263	PyMODINIT_FUNC init18d5a8a6a9092d5ba63e47774ced3130(void){
# 00264	   import_array();
# 00265	   (void) Py_InitModule("18d5a8a6a9092d5ba63e47774ced3130", MyMethods);
# 00266	}
# 00267
# Problem occurred during compilation with the command line below:
# /usr/bin/clang++ -dynamiclib -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -target-feature -sse4a -target-feature -avx512bw -target-feature +cx16 -target-feature -tbm -target-feature +xsave -target-feature -fma4 -target-feature -avx512vl -target-feature +prfchw -target-feature +bmi2 -target-feature +adx -target-feature -xsavec -target-feature +fsgsbase -target-feature +avx -target-feature -avx512cd -target-feature -avx512pf -target-feature -rtm -target-feature +popcnt -target-feature +fma -target-feature +bmi -target-feature +aes -target-feature +rdrnd -target-feature -xsaves -target-feature +sse4.1 -target-feature +sse4.2 -target-feature +avx2 -target-feature -avx512er -target-feature +sse -target-feature +lzcnt -target-feature +pclmul -target-feature -avx512f -target-feature +f16c -target-feature +ssse3 -target-feature +mmx -target-feature +cmov -target-feature -xop -target-feature +rdseed -target-feature +movbe -target-feature -hle -target-feature +xsaveopt -target-feature -sha -target-feature +sse2 -target-feature +sse3 -target-feature -avx512dq -D NPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -undefined dynamic_lookup -I/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/numpy/core/include -I/Users/will/miniconda3/envs/lnet/include/python2.7 -o /Users/will/.theano/compiledir_Darwin-15.4.0-x86_64-i386-64bit-i386-2.7.11-64/tmpnVaeEU/18d5a8a6a9092d5ba63e47774ced3130.so /Users/will/.theano/compiledir_Darwin-15.4.0-x86_64-i386-64bit-i386-2.7.11-64/tmpnVaeEU/mod.cpp -L/Users/will/miniconda3/envs/lnet/lib
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/opt.py", line 1493, in process_node
#     replacements = lopt.transform(node)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/tensor/opt.py", line 4684, in constant_folding
#     no_recycling=[])
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/op.py", line 739, in make_thunk
#     output_storage=node_output_storage)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1073, in make_thunk
#     keep_lock=keep_lock)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1015, in __compile__
#     keep_lock=keep_lock)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1442, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1076, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1354, in compile_cmodule
#     preargs=preargs)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2010, in compile_str
#     (status, compile_stderr.replace('\n', '. ')))
# ...
# 00031
# 00032
# 00033	            this->__ERROR = __ERROR;
# 00034	            return 0;
# 00035	        }
# 00036	        void cleanup(void) {
# 00037	            __label_1:
# 00038
# 00039	double __DUMMY_1;
# 00040	__label_3:
# 00041
# 00042	double __DUMMY_3;
# 00043	__label_6:
# 00044
# 00045	double __DUMMY_6;
# 00046
# 00047	            Py_XDECREF(this->storage_V3);
# 00048	Py_XDECREF(this->storage_V1);
# 00049	        }
# 00050	        int run(void) {
# 00051	            int __failure = 0;
# 00052
# 00053	    PyObject* py_V1;
# 00054
# 00055	        PyArrayObject* V1;
# 00056
# 00057	    PyObject* py_V3;
# 00058
# 00059	        PyArrayObject* V3;
# 00060
# 00061	{
# 00062
# 00063	    py_V1 = PyList_GET_ITEM(storage_V1, 0);
# 00064	    {Py_XINCREF(py_V1);}
# 00065
# 00066	        if (py_V1 == Py_None)
# 00067	        {
# 00068
# 00069	        V1 = NULL;
# 00070
# 00071	        }
# 00072	        else
# 00073	        {
# 00074
# 00075	        V1 = (PyArrayObject*)(py_V1);
# 00076	        Py_XINCREF(V1);
# 00077
# 00078	        }
# 00079
# 00080	{
# 00081
# 00082	    py_V3 = PyList_GET_ITEM(storage_V3, 0);
# 00083	    {Py_XINCREF(py_V3);}
# 00084
# 00085	        V3 = (PyArrayObject*)(py_V3);
# 00086	        Py_XINCREF(V3);
# 00087
# 00088	{
# 00089	// Op class DimShuffle
# 00090	if (PyArray_NDIM(V3) != 0){PyErr_SetString(PyExc_NotImplementedError, "input nd"); {
# 00091	        __failure = 5;
# 00092	        if (!PyErr_Occurred()) {
# 00093	            PyErr_SetString(PyExc_RuntimeError,
# 00094	                "Unexpected error in an Op's C code. "
# 00095	                "No Python exception was set.");
# 00096	            }
# 00097	        goto __label_5;};};
# 00098	if (V1) {Py_XDECREF(V1);};
# 00099	{ PyArrayObject * V3__view_or_copy = (PyArrayObject*)PyArray_FromAny((PyObject*)V3, NULL,0, 0, NPY_ARRAY_ALIGNED|NPY_ARRAY_ENSURECOPY, NULL);
# 00100	npy_intp dimensions[2];
# 00101	dimensions[0] = 1;
# 00102	dimensions[1] = 1;
# 00103	npy_intp strides[2];
# 00104	strides[0] = 0;
# 00105	strides[1] = 0;
# 00106	if (strides[2-1] == 0) strides[2-1] = PyArray_DESCR(V3__view_or_copy)->elsize;
# 00107	if (strides[0] == 0) strides[0] = strides[0+1] * dimensions[0+1];
# 00108	V1 = (PyArrayObject*)PyArray_New(&PyArray_Type, 2, dimensions, PyArray_TYPE(V3__view_or_copy), strides, PyArray_DATA(V3__view_or_copy), PyArray_ITEMSIZE(V3__view_or_copy), (NPY_ARRAY_WRITEABLE*PyArray_ISWRITEABLE(V3__view_or_copy)), NULL);
# 00109	if (V1 == NULL) {
# 00110	        __failure = 5;
# 00111	        if (!PyErr_Occurred()) {
# 00112	            PyErr_SetString(PyExc_RuntimeError,
# 00113	                "Unexpected error in an Op's C code. "
# 00114	                "No Python exception was set.");
# 00115	            }
# 00116	        goto __label_5;};;
# 00117	PyArray_UpdateFlags(V1, NPY_ARRAY_UPDATE_ALL);
# 00118
# 00119	#if NPY_API_VERSION < 0x00000007
# 00120	PyArray_BASE(V1) = (PyObject*)V3__view_or_copy;
# 00121	#else
# 00122	PyArray_SetBaseObject(V1, (PyObject*)V3__view_or_copy);
# 00123	#endif
# 00124	};__label_5:
# 00125
# 00126	double __DUMMY_5;
# 00127
# 00128	}
# 00129	__label_4:
# 00130
# 00131	        if (V3) {
# 00132	            Py_XDECREF(V3);
# 00133	        }
# 00134
# 00135	    {Py_XDECREF(py_V3);}
# 00136
# 00137	double __DUMMY_4;
# 00138
# 00139	}
# 00140	__label_2:
# 00141
# 00142	    if (!__failure) {
# 00143
# 00144	        {Py_XDECREF(py_V1);}
# 00145	        if (!V1) {
# 00146	            Py_INCREF(Py_None);
# 00147	            py_V1 = Py_None;
# 00148	        }
# 00149	        else if ((void*)py_V1 != (void*)V1) {
# 00150	            py_V1 = (PyObject*)V1;
# 00151	        }
# 00152
# 00153	        {Py_XINCREF(py_V1);}
# 00154
# 00155	        if (V1 && !PyArray_ISALIGNED((PyArrayObject*) py_V1)) {
# 00156	            PyErr_Format(PyExc_NotImplementedError,
# 00157	                         "c_sync: expected an aligned array, got non-aligned array of type %ld"
# 00158	                         " with %ld dimensions, with 3 last dims "
# 00159	                         "%ld, %ld, %ld"
# 00160	                         " and 3 last strides %ld %ld, %ld.",
# 00161	                         (long int) PyArray_TYPE((PyArrayObject*) py_V1),
# 00162	                         (long int) PyArray_NDIM(V1),
# 00163	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 00164	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-3] : -1,
# 00165	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 00166	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-2] : -1,
# 00167	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 00168	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-1] : -1,
# 00169	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 00170	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-3] : -1,
# 00171	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 00172	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-2] : -1,
# 00173	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 00174	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-1] : -1
# 00175	        );
# 00176	            {
# 00177	        __failure = 2;
# 00178	        if (!PyErr_Occurred()) {
# 00179	            PyErr_SetString(PyExc_RuntimeError,
# 00180	                "Unexpected error in an Op's C code. "
# 00181	                "No Python exception was set.");
# 00182	            }
# 00183	        goto __label_2;}
# 00184	        }
# 00185
# 00186	      PyObject* old = PyList_GET_ITEM(storage_V1, 0);
# 00187	      {Py_XINCREF(py_V1);}
# 00188	      PyList_SET_ITEM(storage_V1, 0, py_V1);
# 00189	      {Py_XDECREF(old);}
# 00190	    }
# 00191
# 00192	        if (V1) {
# 00193	            Py_XDECREF(V1);
# 00194	        }
# 00195
# 00196	    {Py_XDECREF(py_V1);}
# 00197
# 00198	double __DUMMY_2;
# 00199
# 00200	}
# 00201
# 00202
# 00203	        if (__failure) {
# 00204	            // When there is a failure, this code puts the exception
# 00205	            // in __ERROR.
# 00206	            PyObject* err_type = NULL;
# 00207	            PyObject* err_msg = NULL;
# 00208	            PyObject* err_traceback = NULL;
# 00209	            PyErr_Fetch(&err_type, &err_msg, &err_traceback);
# 00210	            if (!err_type) {err_type = Py_None;Py_INCREF(Py_None);}
# 00211	            if (!err_msg) {err_msg = Py_None; Py_INCREF(Py_None);}
# 00212	            if (!err_traceback) {err_traceback = Py_None; Py_INCREF(Py_None);}
# 00213	            PyObject* old_err_type = PyList_GET_ITEM(__ERROR, 0);
# 00214	            PyObject* old_err_msg = PyList_GET_ITEM(__ERROR, 1);
# 00215	            PyObject* old_err_traceback = PyList_GET_ITEM(__ERROR, 2);
# 00216	            PyList_SET_ITEM(__ERROR, 0, err_type);
# 00217	            PyList_SET_ITEM(__ERROR, 1, err_msg);
# 00218	            PyList_SET_ITEM(__ERROR, 2, err_traceback);
# 00219	            {Py_XDECREF(old_err_type);}
# 00220	            {Py_XDECREF(old_err_msg);}
# 00221	            {Py_XDECREF(old_err_traceback);}
# 00222	        }
# 00223	        // The failure code is returned to index what code block failed.
# 00224	        return __failure;
# 00225
# 00226	        }
# 00227	    };
# 00228	    }
# 00229
# 00230
# 00231	        static int __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130_executor(__struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130* self) {
# 00232	            return self->run();
# 00233	        }
# 00234
# 00235	        static void __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130_destructor(void* executor, void* self) {
# 00236	            delete ((__struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130*)self);
# 00237	        }
# 00238
# 00239	//////////////////////
# 00240	////  Functions
# 00241	//////////////////////
# 00242	static PyObject * instantiate(PyObject * self, PyObject *argtuple) {
# 00243	  assert(PyTuple_Check(argtuple));
# 00244	  if (3 != PyTuple_Size(argtuple)){
# 00245	     PyErr_Format(PyExc_TypeError, "Wrong number of arguments, expected 3, got %i", (int)PyTuple_Size(argtuple));
# 00246	     return NULL;
# 00247	  }
# 00248	  __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130* struct_ptr = new __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130();
# 00249	  if (struct_ptr->init( PyTuple_GET_ITEM(argtuple, 0),PyTuple_GET_ITEM(argtuple, 1),PyTuple_GET_ITEM(argtuple, 2) ) != 0) {
# 00250	    delete struct_ptr;
# 00251	    return NULL;
# 00252	  }
# 00253	  PyObject* thunk = PyCObject_FromVoidPtrAndDesc((void*)(&__struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130_executor), struct_ptr, __struct_compiled_op_18d5a8a6a9092d5ba63e47774ced3130_destructor);
# 00254	  return thunk; }
# 00255
# 00256	//////////////////////
# 00257	////  Module init
# 00258	//////////////////////
# 00259	static PyMethodDef MyMethods[] = {
# 00260		{"instantiate", instantiate, METH_VARARGS, "undocumented"} ,
# 00261		{NULL, NULL, 0, NULL}
# 00262	};
# 00263	PyMODINIT_FUNC init18d5a8a6a9092d5ba63e47774ced3130(void){
# 00264	   import_array();
# 00265	   (void) Py_InitModule("18d5a8a6a9092d5ba63e47774ced3130", MyMethods);
# 00266	}
# 00267
# Problem occurred during compilation with the command line below:
# /usr/bin/clang++ -dynamiclib -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=broadwell -target-feature -sse4a -target-feature -avx512bw -target-feature +cx16 -target-feature -tbm -target-feature +xsave -target-feature -fma4 -target-feature -avx512vl -target-feature +prfchw -target-feature +bmi2 -target-feature +adx -target-feature -xsavec -target-feature +fsgsbase -target-feature +avx -target-feature -avx512cd -target-feature -avx512pf -target-feature -rtm -target-feature +popcnt -target-feature +fma -target-feature +bmi -target-feature +aes -target-feature +rdrnd -target-feature -xsaves -target-feature +sse4.1 -target-feature +sse4.2 -target-feature +avx2 -target-feature -avx512er -target-feature +sse -target-feature +lzcnt -target-feature +pclmul -target-feature -avx512f -target-feature +f16c -target-feature +ssse3 -target-feature +mmx -target-feature +cmov -target-feature -xop -target-feature +rdseed -target-feature +movbe -target-feature -hle -target-feature +xsaveopt -target-feature -sha -target-feature +sse2 -target-feature +sse3 -target-feature -avx512dq -D NPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -undefined dynamic_lookup -I/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/numpy/core/include -I/Users/will/miniconda3/envs/lnet/include/python2.7 -o /Users/will/.theano/compiledir_Darwin-15.4.0-x86_64-i386-64bit-i386-2.7.11-64/tmpb6vPtC/18d5a8a6a9092d5ba63e47774ced3130.so /Users/will/.theano/compiledir_Darwin-15.4.0-x86_64-i386-64bit-i386-2.7.11-64/tmpb6vPtC/mod.cpp -L/Users/will/miniconda3/envs/lnet/lib
# ERROR (theano.gof.opt): Optimization failure due to: constant_folding
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/opt.py", line 1493, in process_node
#     replacements = lopt.transform(node)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/tensor/opt.py", line 4684, in constant_folding
#     no_recycling=[])
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/op.py", line 739, in make_thunk
#     output_storage=node_output_storage)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1073, in make_thunk
#     keep_lock=keep_lock)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1015, in __compile__
#     keep_lock=keep_lock)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1442, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1076, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cc.py", line 1354, in compile_cmodule
#     preargs=preargs)
#   File "/Users/will/miniconda3/envs/lnet/lib/python2.7/site-packages/theano/gof/cmodule.py", line 2010, in compile_str
#     (status, compile_stderr.replace('\n', '. ')))
# Exception: ("Compilation failed (return status=1): clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-sse4a'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-tbm'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-fma4'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-rtm'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-hle'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-sha'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: unknown argument: '-target-feature'. clang: error: no such file or directory: '+cx16'. clang: error: no such file or directory: '+xsave'. clang: error: no such file or directory: '+prfchw'. clang: error: no such file or directory: '+bmi2'. clang: error: no such file or directory: '+adx'. clang: error: language not recognized: 'savec'. clang: error: no such file or directory: '+fsgsbase'. clang: error: no such file or directory: '+avx'. clang: error: no such file or directory: '+popcnt'. clang: error: no such file or directory: '+fma'. clang: error: no such file or directory: '+bmi'. clang: error: no such file or directory: '+aes'. clang: error: no such file or directory: '+rdrnd'. clang: error: language not recognized: 'saves'. clang: error: no such file or directory: '+sse4.1'. clang: error: no such file or directory: '+sse4.2'. clang: error: no such file or directory: '+avx2'. clang: error: no such file or directory: '+sse'. clang: error: no such file or directory: '+lzcnt'. clang: error: no such file or directory: '+pclmul'. clang: error: no such file or directory: '+f16c'. clang: error: no such file or directory: '+ssse3'. clang: error: no such file or directory: '+mmx'. clang: error: no such file or directory: '+cmov'. clang: error: language not recognized: 'op'. clang: error: no such file or directory: '+rdseed'. clang: error: no such file or directory: '+movbe'. clang: error: no such file or directory: '+xsaveopt'. clang: error: no such file or directory: '+sse2'. clang: error: no such file or directory: '+sse3'. ", ' ...
